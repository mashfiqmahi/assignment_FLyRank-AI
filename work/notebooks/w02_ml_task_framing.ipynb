# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/mashfiqmahi/assignment_FLyRank-AI/blob/main/work/notebooks/w02_ml_task_framing.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# *Classification, clustering, ranking, or scoring — which one, and why?*
#
# My lane (Structure Content Archetype Clustering) is a clustering task cause I am not predicting yes/no. According to my understanding, no one has labeled the pages as "champion" or "stale". The model naturally groups the data and then we will take decision which page might be refreshed.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. Target or proxy
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*
# Clustering is an unsupervised technique. So there are no labels or targets in the dataset. Therefore I am not predicting any speicific outcome rather I am finding the structure or pattern of the data. And obviosuly the label will come from observed outcome not from defined rules.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Success metric
#
# *One metric you can defend. What number means 'good'?*
#
# The honest answer is clustering has no ground truth alone, we must need human sense check. My success metric is a silhouette score which ranges from -1 to +1 where higher value mean tighter, better separated cluster. This helps to choose the number of clusters K. For each cluster we explicitly check its median/mode values i.e impressions, ctr, age etc and make sure the group tells a meaningful story eg. high impression + low ctr + old = stale-visible.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
#
#
# *Load your lane's slice and show it: one row = one what?*

# %%
import os, sys, subprocess

IN_COLAB = "google.colab" in sys.modules
REPO_URL = "https://github.com/flyrank-bih/flyrank-ml-internship-starter"
REPO_DIR = "flyrank-ml-internship-starter"

if IN_COLAB:
    if not os.path.isdir(REPO_DIR):
        subprocess.run(["git", "clone", "--depth", "1", REPO_URL, REPO_DIR], check=True)
    os.chdir(REPO_DIR)
    subprocess.run([sys.executable, "-m", "pip", "install", "-q", "-r", "requirements.txt"], check=True)
elif os.path.basename(os.getcwd()) == "notebooks":
    os.chdir("..")

import pandas as pd
import numpy as np

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

print(f"Shape: {df.shape[0]:,} rows, {df.shape[1]} columns")
print(f"Unit of analysis check: {df['content_id'].nunique():,} unique content_id values "
      f"out of {len(df):,} rows -> {'one row per page confirmed' if df['content_id'].nunique()==len(df) else 'DUPLICATES FOUND - investigate'}")

# The columns I plan to actually cluster on (safe, non-label-derived, non-ID)
cluster_features = [
    "impressions_90d", "ctr", "avg_position",
    "days_since_update", "engagement_rate", "content_type",'clicks_90d', 'pageviews_90d', 'sessions_90d', 'users_90d',
]
cluster_features = [c for c in cluster_features if c in df.columns]
print("\nPlanned clustering features:", cluster_features)
df[cluster_features].head(10)
# Out:
# Shape: 30,000 rows, 44 columns
# Unit of analysis check: 30,000 unique content_id values out of 30,000 rows -> one row per page confirmed
#
# Planned clustering features: ['impressions_90d', 'ctr', 'avg_position', 'engagement_rate', 'content_type', 'clicks_90d', 'pageviews_90d', 'sessions_90d', 'users_90d']
#    impressions_90d   ctr  avg_position  engagement_rate     content_type  \
# 0             3803  0.76          10.6             5.88  keyword article
# 1            15320  0.05          20.3             0.00  keyword article
# 2            12581  0.09          36.5             0.00  keyword article
# 3            11751  0.49           6.2             1.28  keyword article
# 4            19140  0.13          44.0             0.00  keyword article
# 5             3970  0.03           8.5             0.00  keyword article
# 6               20  0.00           7.0             0.00  keyword article
# 7             1724  0.06          21.2             3.57  keyword article
# ...

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*
#
# There are multiple features to inspect. By just writing some if-else statement, the decision can not be taken. Writing a rule like flag a page older than 180 days with high impression, these task are already done using health-score by flyrank. I mentioned more than 8 features that i will use for clustering. So writing every possible combination of if-else for these features are not handy. Therefore ML beats a fixed rule here.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
